# %% [markdown]
# # Processing of Twitter Account Data
# In 2022, I made a [Naive Bayes model that detected Twitter bots](https://github.com/karl-aldous-banaag/naive-bayes-twitter-bot-detection/). I revisited my old project and redid the data processing.
#
# For this project, I ysed the output from the data collection in 2022. But, I processed the data in a different way. I prioritized modifying the data in such a way that is more concerned about how the accounts behave.

# %% [markdown]
# ## Importing Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("twitter_output.csv")

# %%
df.head()
# Out:
#                    id account_type                      created_at  \
# 0  787405734442958848          bot  Sat Oct 15 21:32:11 +0000 2016
# 1  796216118331310080        human  Wed Nov 09 05:01:30 +0000 2016
# 2  875949740503859204        human  Sat Jun 17 05:34:27 +0000 2017
# 3  756119643622735875        human  Thu Jul 21 13:32:25 +0000 2016
# 4           464781334        human  Sun Jan 15 16:32:35 +0000 2012
#
#   default_profile default_profile_image  \
# 0           False                 False
# 1           False                 False
# 2           False                 False
# 3            True                 False
# 4           False                 False
#
#                                          description  favourites_count  \
# 0  Blame @MoistHorse, Inspired by @MakingInvisibl...               5.0
# 1  Photographing the American West since 1980. I ...             451.0
# 2  🔥𝖙𝖍𝖊 𝖘𝖆𝖛𝖆𝖌𝖊 𝖌𝖊𝖓𝖙𝖑𝖊𝖒𝖆𝖓🔥                        ...            7426.0
# 3              Wife.Godmother.Friend.Feline Fanatic!           19058.0
# 4  England U21 Assistant Coach | @pumafootball Am...             616.0
#
#    followers_count geo_enabled  lang                 location  \
# 0           1995.0       False   NaN                      NaN
# 1            781.0       False   NaN            United States
# 2            261.0        True   NaN                      NaN
# 3            751.0        True   NaN           Birmingham, AL
# 4         736975.0        True   NaN  England, United Kingdom
#
#                            profile_background_image  \
# 0  http://abs.twimg.com/images/themes/theme1/bg.png
# 1  http://abs.twimg.com/images/themes/theme1/bg.png
# 2  http://abs.twimg.com/images/themes/theme1/bg.png
# 3                                               NaN
# 4  http://abs.twimg.com/images/themes/theme1/bg.png
#
#                                        profile_image      screen_name  \
# 0  http://pbs.twimg.com/profile_images/7874121826...  best_in_dumbest
# 1  http://pbs.twimg.com/profile_images/8023296328...     CJRubinPhoto
# 2  http://pbs.twimg.com/profile_images/1579338210...         SVGEGENT
# 3  http://pbs.twimg.com/profile_images/1284884924...      TinkTinkEDU
# 4  http://pbs.twimg.com/profile_images/1437799096...    JoleonLescott
#
#    statuses_count verified  average_tweets_per_day  account_age
# 0         17209.0    False                     NaN          NaN
# 1           251.0    False                     NaN          NaN
# 2          1499.0    False                     NaN          NaN
# 3          2531.0    False                     NaN          NaN
# 4          4750.0     True                     NaN          NaN

# %% [markdown]
# ## Removal of Unnecessary Columns
# For this dataset, I will remove `default_profile`, `default_profile_image`, `description`, `geo_enabled`, `lang`, `location`, `profile_background_image`, `profile_image`, `average_tweets_per_day`, `account_age`, and `created_at`. Below are the reasons why these columns will be deleted.
#
# #### default_profile
# Bot accounts are likely to change their profile pictures to imitate human accounts. Thus, the profile picture is not relevant in the behavior displayed in the account.
#
# #### default_profile_image
# Bot accounts are likely to change their profile pictures to imitate human accounts. Thus, the profile picture is not relevant in the behavior displayed in the account.
#
# #### description
# The description does not have an effect on the behavior of the account.
#
# #### geo_enabled
# This column does not provide any information about the behavior of the account.
#
# #### lang
# The language of the Twitter account does not provide any insights about the nature of the Twitter account.
#
# #### location
# Many values in this column are blank or do not provide any information about the location of the account.
#
# #### profile_background_image
# The presence or absence of a background image does not affect the behavior displayed in the account.
#
# #### average_tweets_per_day
# This column contains no data, but the values of this column will be computed later. To compute for this column, I will count the days between the date in `created_at` and October 25, 2022 (the day when this dataset was created).
#
# #### account_age
# This column contains no data, but the values of this column will be computed later.
#
# #### created_at
# Bots can be old or new. Regardless, this will not be important since `account_age` will be computed later. However, this column will stay in the beggining of this notebook so that I can derive `average_tweets_per_day` and `account_age`.

# %%
df.drop(
    labels = [
        "default_profile", "default_profile_image", "description", "geo_enabled",
        "lang", "location", "profile_background_image", "profile_image",
        "average_tweets_per_day", "account_age"
    ],
    axis = "columns"
).head()
# Out:
#                    id account_type                      created_at  \
# 0  787405734442958848          bot  Sat Oct 15 21:32:11 +0000 2016
# 1  796216118331310080        human  Wed Nov 09 05:01:30 +0000 2016
# 2  875949740503859204        human  Sat Jun 17 05:34:27 +0000 2017
# 3  756119643622735875        human  Thu Jul 21 13:32:25 +0000 2016
# 4           464781334        human  Sun Jan 15 16:32:35 +0000 2012
#
#    favourites_count  followers_count      screen_name  statuses_count verified
# 0               5.0           1995.0  best_in_dumbest         17209.0    False
# 1             451.0            781.0     CJRubinPhoto           251.0    False
# 2            7426.0            261.0         SVGEGENT          1499.0    False
# 3           19058.0            751.0      TinkTinkEDU          2531.0    False
# 4             616.0         736975.0    JoleonLescott          4750.0     True

# %% [markdown]
# The code above dropped the unnecessary columns, so it is safe to set `df` to
# `df.drop(labels = ["default_profile", "default_profile_image", "geo_enabled", "lang", "location", "profile_background_image", "profile_image", "average_tweets_per_day", "account_age"], axis = "columns")`.

# %%
df = df.drop(
    labels = [
        "default_profile", "default_profile_image", "description", "geo_enabled",
        "lang", "location", "profile_background_image", "profile_image",
        "average_tweets_per_day", "account_age"
    ],
    axis = "columns"
)

# %% [markdown]
# ## Modifying Dataset

# %% [markdown]
# ### Converting `created_at` to datetime

# %%
df.dtypes
# Out:
# id                    int64
# account_type         object
# created_at           object
# favourites_count    float64
# followers_count     float64
# screen_name          object
# statuses_count      float64
# verified             object
# dtype: object

# %% [markdown]
# `created_at` has a type of object, so I will convert it to datetime using the `pd.to_datetime` function.

# %%
df["created_at"] = pd.to_datetime(df["created_at"])

# %% [markdown]
# The code below verifies that the column was converted successfully.

# %%
df.dtypes
# Out:
# id                                int64
# account_type                     object
# created_at          datetime64[ns, UTC]
# favourites_count                float64
# followers_count                 float64
# screen_name                      object
# statuses_count                  float64
# verified                         object
# dtype: object

# %% [markdown]
# ### Dropping Rows with Missing Values

# %% [markdown]
# Before I remove rows with missing values, I first want to check how many values I have at the moment.

# %%
len(df)
# Out:
# 37438

# %% [markdown]
# After checking the number of rows, I want to see how many rows I will lose when I remove the rows with missing values.

# %%
pd.DataFrame(df.isnull().sum())
# Out:
#                      0
# id                   0
# account_type         0
# created_at        1788
# favourites_count  1788
# followers_count   1788
# screen_name       1788
# statuses_count    1788
# verified          1788

# %% [markdown]
# I will only lose <b>1788</b> rows. I ignored the missing values in the `description` column since Twitter accounts can exist without descriptions. So, I decided to remove the columns with missing values.

# %%
df = df.dropna(subset=["created_at", "favourites_count", "followers_count", "screen_name", "statuses_count", "verified"])

# %% [markdown]
# ### Count Age of Accounts in Days

# %%
import datetime
import numpy as np
import math

# %%
pd.to_datetime("Oct 25 0:00:00 +0000 2022")
# Out:
# Timestamp('2022-10-25 00:00:00+0000', tz='UTC')

# %% [markdown]
# #### Computing

# %%
df["account_age"] = ((pd.to_datetime("Oct 25 0:00:00 +0000 2022") - df["created_at"]) / np.timedelta64(1, 'D')).astype(int)

# %%
df.head()
# Out:
#                    id account_type                created_at  \
# 0  787405734442958848          bot 2016-10-15 21:32:11+00:00
# 1  796216118331310080        human 2016-11-09 05:01:30+00:00
# 2  875949740503859204        human 2017-06-17 05:34:27+00:00
# 3  756119643622735875        human 2016-07-21 13:32:25+00:00
# 4           464781334        human 2012-01-15 16:32:35+00:00
#
#    favourites_count  followers_count      screen_name  statuses_count  \
# 0               5.0           1995.0  best_in_dumbest         17209.0
# 1             451.0            781.0     CJRubinPhoto           251.0
# 2            7426.0            261.0         SVGEGENT          1499.0
# 3           19058.0            751.0      TinkTinkEDU          2531.0
# 4             616.0         736975.0    JoleonLescott          4750.0
#
#   verified  account_age
# 0    False         2200
# 1    False         2175
# 2    False         1955
# 3    False         2286
# 4     True         3935

# %% [markdown]
# ### Removing `created_at` Column
# Now that I have the `account_age` column, I do not need the `created_at` column any longer.

# %%
df = df.drop(labels = ["created_at"], axis = "columns")
df.head()
# Out:
#                    id account_type  favourites_count  followers_count  \
# 0  787405734442958848          bot               5.0           1995.0
# 1  796216118331310080        human             451.0            781.0
# 2  875949740503859204        human            7426.0            261.0
# 3  756119643622735875        human           19058.0            751.0
# 4           464781334        human             616.0         736975.0
#
#        screen_name  statuses_count verified  account_age
# 0  best_in_dumbest         17209.0    False         2200
# 1     CJRubinPhoto           251.0    False         2175
# 2         SVGEGENT          1499.0    False         1955
# 3      TinkTinkEDU          2531.0    False         2286
# 4    JoleonLescott          4750.0     True         3935

# %% [markdown]
# ### Computing for Average Number of Posts per Day

# %%
df["average_tweets_per_day"] = df["statuses_count"] / df["account_age"]
df.head()
# Out:
#                    id account_type  favourites_count  followers_count  \
# 0  787405734442958848          bot               5.0           1995.0
# 1  796216118331310080        human             451.0            781.0
# 2  875949740503859204        human            7426.0            261.0
# 3  756119643622735875        human           19058.0            751.0
# 4           464781334        human             616.0         736975.0
#
#        screen_name  statuses_count verified  account_age  \
# 0  best_in_dumbest         17209.0    False         2200
# 1     CJRubinPhoto           251.0    False         2175
# 2         SVGEGENT          1499.0    False         1955
# 3      TinkTinkEDU          2531.0    False         2286
# 4    JoleonLescott          4750.0     True         3935
#
#    average_tweets_per_day
# 0                7.822273
# 1                0.115402
# 2                0.766752
# 3                1.107174
# 4                1.207116

# %% [markdown]
# If the `statuses_count` and `average_tweets_per_day` columns were to coexist while making the model, the number of tweets would be considered in two columns of the dataset. So, I must remove the `statuses_count` column.

# %%
df = df.drop(labels = ["statuses_count"], axis = "columns")
df.head()
# Out:
#                    id account_type  favourites_count  followers_count  \
# 0  787405734442958848          bot               5.0           1995.0
# 1  796216118331310080        human             451.0            781.0
# 2  875949740503859204        human            7426.0            261.0
# 3  756119643622735875        human           19058.0            751.0
# 4           464781334        human             616.0         736975.0
#
#        screen_name verified  account_age  average_tweets_per_day
# 0  best_in_dumbest    False         2200                7.822273
# 1     CJRubinPhoto    False         2175                0.115402
# 2         SVGEGENT    False         1955                0.766752
# 3      TinkTinkEDU    False         2286                1.107174
# 4    JoleonLescott     True         3935                1.207116

# %% [markdown]
# ### Computing for Average Liking of Tweets per Day

# %%
df["average_tweets_liked_per_day"] = df["favourites_count"] / df["account_age"]
df.head()
# Out:
#                    id account_type  favourites_count  followers_count  \
# 0  787405734442958848          bot               5.0           1995.0
# 1  796216118331310080        human             451.0            781.0
# 2  875949740503859204        human            7426.0            261.0
# 3  756119643622735875        human           19058.0            751.0
# 4           464781334        human             616.0         736975.0
#
#        screen_name verified  account_age  average_tweets_per_day  \
# 0  best_in_dumbest    False         2200                7.822273
# 1     CJRubinPhoto    False         2175                0.115402
# 2         SVGEGENT    False         1955                0.766752
# 3      TinkTinkEDU    False         2286                1.107174
# 4    JoleonLescott     True         3935                1.207116
#
#    average_tweets_liked_per_day
# 0                      0.002273
# 1                      0.207356
# 2                      3.798465
# 3                      8.336833
# 4                      0.156544

# %% [markdown]
# If the `favourites_count` and `average_tweets_liked_per_day` columns were to coexist while making the model, the number of liked tweets would be considered in two columns. So, I must remove the `favourites_count` column.

# %%
df = df.drop(labels = ["favourites_count"], axis = "columns")
df.head()
# Out:
#                    id account_type  followers_count      screen_name verified  \
# 0  787405734442958848          bot           1995.0  best_in_dumbest    False
# 1  796216118331310080        human            781.0     CJRubinPhoto    False
# 2  875949740503859204        human            261.0         SVGEGENT    False
# 3  756119643622735875        human            751.0      TinkTinkEDU    False
# 4           464781334        human         736975.0    JoleonLescott     True
#
#    account_age  average_tweets_per_day  average_tweets_liked_per_day
# 0         2200                7.822273                      0.002273
# 1         2175                0.115402                      0.207356
# 2         1955                0.766752                      3.798465
# 3         2286                1.107174                      8.336833
# 4         3935                1.207116                      0.156544

# %% [markdown]
# ## Write Clean Data as .csv File

# %%
df.to_csv("twitter_output_clean.csv", index = False)
